# %%
import numpy as np

# %%
class RNN:
    def __init__(self, Wx, Wh, b):
        self.param = [Wx, Wh, b]
        self.grads = [np.zeroes_like(Wx), np.zeroes_like(Wh), np.zeroes_like(b)]
        self.cache = None
        
    def forward(self, x, h_prev):
        Wx, Wh, b = self.param
        t = np.matmul(h_prev, Wh) + np.matmul(x, Wx) + b
        h_next = np.tanh(t)
        
        self.cache = (x, h_prev, h_next)
        return h_next
    
    def backward(self, dh_next):
        Wx, Wh, b = self.param
        x, h_prev, h_next = self.cache
        
        dt = dh_next * (1 - h_next ** 2)
        db = np.sum(dt, axis=0)
        
        dWh = np.matmul(h_prev.T, dt)
        dh_prev = np.matmul(dt, Wh.T)
        dWx = np.matmul(x.T, dt) # 순서가 다른 이유 
        dx = np.matmul(dt, Wx.T)
        
        self.grads[0][...] = dWx
        self.grads[1][...] = dWh
        self.grads[2][...] = db
        
        return dx, dh_prev

# %% [markdown]
# ### 5.3.2. Time RNN 계층 구현
# - T개의 RNN 계층으로 구성 (T는 임의의 수)
# - 이 책에서는 은닉 상태를 인계 받을지 여부를 stateful이라는 인수로 조정 가능

# %%
class TimeRNN:
    def __init__(self, Wx, Wh, b, stateful=False):
        self.params = [Wx, Wh, Wb]
        self.grads = [np.zeros_like(Wx), np.zeros_like(Wh), np.zeros_like(b)]
        self.layes = None # 다수의 RNN 계층을 list로 저장하는 용도 
        
        self.h = None # forward() 호출 시 마지막 RNN 계층의 은닉 상태 저장 
        self.dh = None # backward() 호출 시 하나 앞 블록의 은닉 상태 기울기 저장 
        self.stateful = stateful
        
    def set_state(self, h):
        self.h = h
        
    def reset_state(self):
        self.h = None
        
    def forward(self, xs):
        Wx, Wh, b = self.params
        N, T, D = xs.shape
        D, H = Wx.shape
        
        self.layes = []
        hs = np.empty((N, T, H), dtype='f')
        
        if not self.stateful or self.h is None:
            self.h = np.zeros((N, H), dtype='f')
            
        for t in range(T):
            layer = RNN(*self.params)
            self.h = layer.forward(xs[:, t, :], self.h)
            hs[:, t, :] = self.h
            self.layers.append(layer)
            
        return hs
    
    def backward(self, dhs):
        Wx, Wh, b = self.params
        N, T, H = dhs.shape
        D, H = Wx.shape
        
        dxs = np.empty((N, T, D), dtype='f')
        dh = 0
        grads = [0, 0, 0]
        
        for t in reveresd(range(T)):
            layer = self.layes[t]
            dx, dh = layer.backward(dhs[:, t, :] + dh) # 합산된 기울기 
            dxs[:, t, :] = dx
            
            for i, grad in enumerate(layer.grads):
                grads[i] += grad
                
        for i, grad in enumerate(grads):
            self.grads[i][...] = grad
            
        self.dh = dh
        
        return dxs

# %% [markdown]
# ## 5.4 시계열 데이터 처리 계층 구현
# - 이번 장의 목표는 RNN 사용하여 '언어 모델' 구현
#
# ### 5.4.1 RNNLM의 전체 그림
# - RNN 계층 외에도 몇 가지 계층이 추가적으로 필요하다
# ![image.png](attachment:image.png)
#
# - Embedding: 단어 ID를 단어의 분산 표현(단어 벡터)으로 변환
# - Affine: RNN 계층이 위로 출력한 은닉 상태를 Softmax 계층으로 전달
#
# ### 5.4.2 Time 계층 구현
# - 위의 계층들을 모두 Time blabla로 묶을 수 있음

# %% [markdown]
# ## 5.5 RNNLM 학습과 평가
# ### 5.5.1 RNNLM 구현
# - 하기 코드의 실제 동작은 경로에 common 폴더를 복사하신 후 테스트 부탁 드립니다.

# %%
import sys
sys.path.append("..")
import numpy as np
from common.time_layers import *

class SimpleRnnlm:
    def __init__(self, vocab_size, wordvec_size, hidden_size):
        V, D, H = vocab_size, wordvec_size, hidden_size
        rn = np.random.randn
        
        # 가중치 초기화 
        embed_W = (rn(V, D) / 100).astype('f')
        
        rnn_Wx = (rn(D, H) / np.sqrt(D)).astype('f') # Xavier 초기값
        rnn_Wh = (rn(H, H) / np.sqrt(H)).astype('f')
        rnn_b = np.zeros(H).astype('f')
        
        affine_W = (rn(H, V) / np.sqrt(H)).astype('f')
        affine_b = np.zeros(V).astype('f')
        
        self.layers = [
            TimeEmbedding(embed_W),
            TimeRNN(rnn_Wx, rnn_Wh, rnn_b, stateful=True),
            TimeAffine(affine_W, affine_b)
        ]
        self.loss_layer = TimeSoftmaxWithLoss()
        self.rnn_layer = self.layers[1]
        self.params, self.grads = [], []
        
        for layer in self.layers:
            self.params += layer.params
            self.grads += layer.grads
            
    def forward(self, xs, ts):
        for layer in self.layers:
            xs = layer.forward(xs)
        loss = self.loss_layer.forward(xs, ts)
        return loss
    
    def backward(self, dout=1):
        dout = self.loss_layer.backward(dout)
        for layer in reversed(self.layers):
            dout = layer.backward(dout)
        return dout
    
    def reset_state(self):
        self.rnn_layer.reset_state()

# %% [markdown]
# ### 5.5.2 언어 모델의 평가
# - 언어 모델은 주어진 과거 단어(정보)로 부터 다음에 출현할 단어의 확률분포를 출력
# #### 퍼플렉서티(Perplexity, 혼란도)
# - 확률의 역수 (분기의 수, number of branches): 입력 데이터가 하나일 경우
# - 헷갈리는 정도
# - https://wikidocs.net/21697
